# %% [markdown]
# # Exercise 6: One Versus All MNIST
# The second part of this exercise is to compare the built-in binarization scheme used for the SVC class, namely one-vs-one, against the one-vs-all scheme, which was discussed in Lecture 5. You should implement your own version of one-vs-all SVM and compare your results
# against the built in version. To make the comparison simple you should keep the same hyperparameters which
# you found in the first part of this exercise. Which was the best classifier? If studying the confusion matrix
# was there any apparent difference between the two methods in terms of misclassifications? Include your findings
# either as comments in your code, in your Jupyter notebook or as a separate text document.
#
# ## Import Data

# %%
import os
import gzip
import numpy as np
from sklearn.preprocessing import StandardScaler

def load_mnist(path, kind="train"):
    labels_path = os.path.join(path, "%s-labels-idx1-ubyte.gz" % kind)
    images_path = os.path.join(path, "%s-images-idx3-ubyte.gz" % kind)

    with gzip.open(labels_path, "rb") as lbpath:
        labels = np.frombuffer(lbpath.read(), dtype=np.uint8, offset=8)

    with gzip.open(images_path, "rb") as imgpath:
        images = np.frombuffer(imgpath.read(), dtype=np.uint8, offset=16).reshape(
            len(labels), 784
        )

    return images, labels


path = "./../resources/datasets/MNIST/"

X_train, y_train = load_mnist(path, kind="train")
X_test, y_test = load_mnist(path, kind="t10k")

# Normalize the data using standard deviation
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Part 1: Hyperparameter Tuning

# %% [markdown]
# ## Grid Search
#
# Prepare Data

# %%
from sklearn.model_selection import train_test_split

# Take a smaller chunk of the training dataset for grid search
X_train_small, _, y_train_small, _ = train_test_split(X_train_scaled, y_train, test_size=0.9, random_state=1945)

# Note: On Windows, verbose output is only functional with n_jobs=1
# Use n_jobs=1 for debugging (single core) and n_jobs=-1 for full performance (all cores)
n_jobs = -1 # Number of cores to use for parallelization

# %% [markdown]
# ### Iteration 1
# Start with broad range of values spread in powers of 10.

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'gamma': [0.0001, 0.001, 0.01, 0.1, 1]
}

grid_search = GridSearchCV(SVC(kernel='rbf'), param_grid, cv=5, n_jobs=n_jobs, verbose=2)
grid_search.fit(X_train_small, y_train_small)

best_params = grid_search.best_params_
best_score = grid_search.best_score_ * 100
print(f"Best parameters found: {best_params}")
print(f"Best cross-validation accuracy: {best_score:.2f}%")
# Out:
# Fitting 5 folds for each of 35 candidates, totalling 175 fits
# [CV] END ..............................C=0.001, gamma=0.0001; total time=  44.1s
# [CV] END ..............................C=0.001, gamma=0.0001; total time=  44.4s
# [CV] END ..............................C=0.001, gamma=0.0001; total time=  44.4s
# [CV] END ..............................C=0.001, gamma=0.0001; total time=  45.4s
# [CV] END ...............................C=0.001, gamma=0.001; total time=  45.7s
# [CV] END ..............................C=0.001, gamma=0.0001; total time=  45.9s
# [CV] END ...............................C=0.001, gamma=0.001; total time=  46.3s
# [CV] END ...............................C=0.001, gamma=0.001; total time=  46.6s
# [CV] END ................................C=0.001, gamma=0.01; total time=  46.3s
# [CV] END ...............................C=0.001, gamma=0.001; total time=  46.6s
# [CV] END ...............................C=0.001, gamma=0.001; total time=  47.0s
# [CV] END ................................C=0.001, gamma=0.01; total time=  45.5s
# [CV] END ................................C=0.001, gamma=0.01; total time=  45.8s
# [CV] END ................................C=0.001, gamma=0.01; total time=  46.5s
# [CV] END ................................C=0.001, gamma=0.01; total time=  46.2s
# [CV] END .................................C=0.001, gamma=0.1; total time=  46.1s
# [CV] END .................................C=0.001, gamma=0.1; total time=  43.6s
# [CV] END .................................C=0.001, gamma=0.1; total time=  44.1s
# [CV] END ...................................C=0.001, gamma=1; total time=  44.9s
# [CV] END .................................C=0.001, gamma=0.1; total time=  45.2s
# [CV] END .................................C=0.001, gamma=0.1; total time=  45.5s
# [CV] END ...................................C=0.001, gamma=1; total time=  45.6s
# [CV] END ...................................C=0.001, gamma=1; total time=  45.6s
# [CV] END ...................................C=0.001, gamma=1; total time=  45.9s
# [CV] END ...............................C=0.01, gamma=0.0001; total time=  44.7s
# [CV] END ...................................C=0.001, gamma=1; total time=  45.3s
# [CV] END ...............................C=0.01, gamma=0.0001; total time=  44.6s
# [CV] END ...............................C=0.01, gamma=0.0001; total time=  45.7s
# [CV] END ...............................C=0.01, gamma=0.0001; total time=  45.7s
# [CV] END ...............................C=0.01, gamma=0.0001; total time=  44.6s
# [CV] END ................................C=0.01, gamma=0.001; total time=  45.1s
# [CV] END ................................C=0.01, gamma=0.001; total time=  44.5s
# [CV] END ................................C=0.01, gamma=0.001; total time=  44.1s
# [CV] END ................................C=0.01, gamma=0.001; total time=  44.9s
# [CV] END ................................C=0.01, gamma=0.001; total time=  45.0s
# [CV] END .................................C=0.01, gamma=0.01; total time=  44.4s
# [CV] END .................................C=0.01, gamma=0.01; total time=  45.7s
# [CV] END .................................C=0.01, gamma=0.01; total time=  45.4s
# [CV] END .................................C=0.01, gamma=0.01; total time=  46.0s
# [CV] END .................................C=0.01, gamma=0.01; total time=  46.2s
# [CV] END ..................................C=0.01, gamma=0.1; total time=  50.3s
# [CV] END ..................................C=0.01, gamma=0.1; total time=  49.5s
# [CV] END ..................................C=0.01, gamma=0.1; total time=  50.4s
# [CV] END ..................................C=0.01, gamma=0.1; total time=  50.5s
# [CV] END ..................................C=0.01, gamma=0.1; total time=  50.9s
# [CV] END ....................................C=0.01, gamma=1; total time=  50.9s
# [CV] END ....................................C=0.01, gamma=1; total time=  50.3s
# [CV] END ....................................C=0.01, gamma=1; total time=  50.7s
# [CV] END .................................C=0.1, gamma=0.001; total time=  28.9s
# [CV] END ................................C=0.1, gamma=0.0001; total time=  48.2s
# [CV] END ................................C=0.1, gamma=0.0001; total time=  47.8s
# [CV] END ................................C=0.1, gamma=0.0001; total time=  46.4s
# [CV] END ................................C=0.1, gamma=0.0001; total time=  46.9s
# [CV] END ................................C=0.1, gamma=0.0001; total time=  47.0s
# [CV] END ....................................C=0.01, gamma=1; total time=  53.5s
# [CV] END ....................................C=0.01, gamma=1; total time=  53.2s
# [CV] END .................................C=0.1, gamma=0.001; total time=  25.4s
# [CV] END .................................C=0.1, gamma=0.001; total time=  25.7s
# [CV] END .................................C=0.1, gamma=0.001; total time=  26.5s
# [CV] END .................................C=0.1, gamma=0.001; total time=  27.0s
# [CV] END ..................................C=0.1, gamma=0.01; total time=  43.8s
# [CV] END ..................................C=0.1, gamma=0.01; total time=  44.7s
# [CV] END ..................................C=0.1, gamma=0.01; total time=  44.5s
# [CV] END ..................................C=0.1, gamma=0.01; total time=  44.6s
# [CV] END ..................................C=0.1, gamma=0.01; total time=  42.7s
# [CV] END ...................................C=0.1, gamma=0.1; total time=  50.8s
# [CV] END ...................................C=0.1, gamma=0.1; total time=  50.7s
# [CV] END ...................................C=0.1, gamma=0.1; total time=  51.0s
# [CV] END ...................................C=0.1, gamma=0.1; total time=  51.9s
# [CV] END .....................................C=0.1, gamma=1; total time=  51.3s
# [CV] END ..................................C=1, gamma=0.0001; total time=  20.5s
# [CV] END ...................................C=0.1, gamma=0.1; total time=  52.6s
# [CV] END .....................................C=0.1, gamma=1; total time=  52.3s
# [CV] END .....................................C=0.1, gamma=1; total time=  50.4s
# [CV] END ...................................C=1, gamma=0.001; total time=  14.4s
# [CV] END ...................................C=1, gamma=0.001; total time=  14.4s
# [CV] END ..................................C=1, gamma=0.0001; total time=  20.6s
# [CV] END ..................................C=1, gamma=0.0001; total time=  20.6s
# [CV] END ..................................C=1, gamma=0.0001; total time=  20.7s
# [CV] END ..................................C=1, gamma=0.0001; total time=  21.5s
# [CV] END .....................................C=0.1, gamma=1; total time=  51.3s
# [CV] END ...................................C=1, gamma=0.001; total time=  14.5s
# [CV] END .....................................C=0.1, gamma=1; total time=  52.2s
# [CV] END ...................................C=1, gamma=0.001; total time=  16.1s
# [CV] END ...................................C=1, gamma=0.001; total time=  17.2s
# [CV] END ....................................C=1, gamma=0.01; total time=  48.9s
# [CV] END ....................................C=1, gamma=0.01; total time=  49.5s
# [CV] END ....................................C=1, gamma=0.01; total time=  48.8s
# [CV] END ....................................C=1, gamma=0.01; total time=  47.3s
# [CV] END ....................................C=1, gamma=0.01; total time=  48.2s
# [CV] END .....................................C=1, gamma=0.1; total time=  54.3s
# [CV] END .....................................C=1, gamma=0.1; total time=  52.8s
# [CV] END .....................................C=1, gamma=0.1; total time=  52.8s
# [CV] END .................................C=10, gamma=0.0001; total time=   9.9s
# [CV] END .................................C=10, gamma=0.0001; total time=  10.7s
# [CV] END .................................C=10, gamma=0.0001; total time=  10.0s
# [CV] END .....................................C=1, gamma=0.1; total time=  51.6s
# [CV] END .......................................C=1, gamma=1; total time=  50.9s
# [CV] END .....................................C=1, gamma=0.1; total time=  51.6s
# [CV] END .......................................C=1, gamma=1; total time=  50.9s
# [CV] END .......................................C=1, gamma=1; total time=  50.3s
# [CV] END .................................C=10, gamma=0.0001; total time=   9.5s
# [CV] END .................................C=10, gamma=0.0001; total time=   9.6s
# [CV] END ..................................C=10, gamma=0.001; total time=  11.4s
# [CV] END ..................................C=10, gamma=0.001; total time=  11.8s
# [CV] END .......................................C=1, gamma=1; total time=  51.4s
# [CV] END ..................................C=10, gamma=0.001; total time=  11.6s
# [CV] END .......................................C=1, gamma=1; total time=  51.1s
# [CV] END ..................................C=10, gamma=0.001; total time=  12.1s
# [CV] END ..................................C=10, gamma=0.001; total time=  12.2s
# [CV] END ...................................C=10, gamma=0.01; total time=  44.4s
# [CV] END ...................................C=10, gamma=0.01; total time=  43.8s
# [CV] END ...................................C=10, gamma=0.01; total time=  44.3s
# [CV] END ...................................C=10, gamma=0.01; total time=  44.1s
# [CV] END ...................................C=10, gamma=0.01; total time=  43.8s
# [CV] END ....................................C=10, gamma=0.1; total time=  49.6s
# [CV] END ....................................C=10, gamma=0.1; total time=  49.2s
# [CV] END ....................................C=10, gamma=0.1; total time=  49.5s
# [CV] END ................................C=100, gamma=0.0001; total time=   7.3s
# [CV] END ................................C=100, gamma=0.0001; total time=   7.6s
# [CV] END ................................C=100, gamma=0.0001; total time=   7.4s
# [CV] END ................................C=100, gamma=0.0001; total time=   7.4s
# [CV] END ....................................C=10, gamma=0.1; total time=  49.4s
# [CV] END ....................................C=10, gamma=0.1; total time=  49.3s
# [CV] END ................................C=100, gamma=0.0001; total time=   7.7s
# [CV] END ......................................C=10, gamma=1; total time=  49.7s
# [CV] END ......................................C=10, gamma=1; total time=  49.3s
# [CV] END ......................................C=10, gamma=1; total time=  48.8s
# [CV] END .................................C=100, gamma=0.001; total time=  11.5s
# [CV] END ......................................C=10, gamma=1; total time=  48.5s
# [CV] END .................................C=100, gamma=0.001; total time=  11.7s
# [CV] END .................................C=100, gamma=0.001; total time=  11.4s
# [CV] END .................................C=100, gamma=0.001; total time=  11.6s
# [CV] END ......................................C=10, gamma=1; total time=  49.8s
# [CV] END .................................C=100, gamma=0.001; total time=  11.5s
# [CV] END ..................................C=100, gamma=0.01; total time=  43.1s
# [CV] END ..................................C=100, gamma=0.01; total time=  44.1s
# [CV] END ..................................C=100, gamma=0.01; total time=  43.7s
# [CV] END ..................................C=100, gamma=0.01; total time=  44.4s
# [CV] END ..................................C=100, gamma=0.01; total time=  44.6s
# [CV] END ...................................C=100, gamma=0.1; total time=  52.1s
# [CV] END ...................................C=100, gamma=0.1; total time=  52.0s
# [CV] END ...................................C=100, gamma=0.1; total time=  51.7s
# [CV] END ...............................C=1000, gamma=0.0001; total time=   8.2s
# [CV] END ...............................C=1000, gamma=0.0001; total time=   9.8s
# [CV] END ...............................C=1000, gamma=0.0001; total time=   7.8s
# [CV] END ...............................C=1000, gamma=0.0001; total time=   8.3s
# [CV] END ...................................C=100, gamma=0.1; total time=  55.6s
# [CV] END .....................................C=100, gamma=1; total time=  55.9s
# [CV] END ...............................C=1000, gamma=0.0001; total time=   9.0s
# [CV] END ...................................C=100, gamma=0.1; total time=  56.7s
# [CV] END .....................................C=100, gamma=1; total time=  57.3s
# [CV] END .....................................C=100, gamma=1; total time=  57.4s
# [CV] END ................................C=1000, gamma=0.001; total time=  14.1s
# [CV] END .....................................C=100, gamma=1; total time=  56.3s
# [CV] END .....................................C=100, gamma=1; total time=  56.4s
# [CV] END ................................C=1000, gamma=0.001; total time=  13.7s
# [CV] END ................................C=1000, gamma=0.001; total time=  13.7s
# [CV] END ................................C=1000, gamma=0.001; total time=  13.5s
# [CV] END ................................C=1000, gamma=0.001; total time=  13.0s
# [CV] END .................................C=1000, gamma=0.01; total time=  44.0s
# [CV] END .................................C=1000, gamma=0.01; total time=  45.5s
# [CV] END .................................C=1000, gamma=0.01; total time=  44.3s
# [CV] END .................................C=1000, gamma=0.01; total time=  44.9s
# [CV] END .................................C=1000, gamma=0.01; total time=  45.4s
# [CV] END ..................................C=1000, gamma=0.1; total time=  51.2s
# [CV] END ..................................C=1000, gamma=0.1; total time=  51.7s
# [CV] END ..................................C=1000, gamma=0.1; total time=  51.7s
# [CV] END ..................................C=1000, gamma=0.1; total time=  46.0s
# [CV] END ..................................C=1000, gamma=0.1; total time=  44.7s
# [CV] END ....................................C=1000, gamma=1; total time=  44.1s
# [CV] END ....................................C=1000, gamma=1; total time=  44.4s
# [CV] END ....................................C=1000, gamma=1; total time=  42.6s
# [CV] END ....................................C=1000, gamma=1; total time=  37.7s
# [CV] END ....................................C=1000, gamma=1; total time=  38.1s
# Best parameters found: {'C': 10, 'gamma': 0.001}
# Best cross-validation accuracy: 93.27%

# %% [markdown]
# Best parameters found are C = 10 and gamma = 0.001, yielding an accuracy of 93.27%
#
# ### Iteration 2
#
# Now, let's explore the values close to this combination to try and further improve the accuracy

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [5, 8, 9, 10, 11, 12, 15],
    'gamma': [0.0005, 0.0008, 0.0009, 0.001, 0.0011, 0.0012, 0.0015]
}

grid_search = GridSearchCV(SVC(kernel='rbf'), param_grid, cv=5, n_jobs=n_jobs, verbose=2)
grid_search.fit(X_train_small, y_train_small)

best_params = grid_search.best_params_
best_score = grid_search.best_score_ * 100
print(f"Best parameters found: {best_params}")
print(f"Best cross-validation accuracy: {best_score:.2f}%")
# Out:
# Fitting 5 folds for each of 49 candidates, totalling 245 fits
# [CV] END ..................................C=5, gamma=0.0005; total time=   9.2s
# [CV] END ..................................C=5, gamma=0.0005; total time=   9.6s
# [CV] END ..................................C=5, gamma=0.0005; total time=   9.8s
# [CV] END ..................................C=5, gamma=0.0005; total time=   9.9s
# [CV] END ..................................C=5, gamma=0.0005; total time=  10.4s
# [CV] END ..................................C=5, gamma=0.0008; total time=  10.6s
# [CV] END ..................................C=5, gamma=0.0008; total time=  11.2s
# [CV] END ..................................C=5, gamma=0.0008; total time=  11.3s
# [CV] END ..................................C=5, gamma=0.0008; total time=  10.4s
# [CV] END ..................................C=5, gamma=0.0008; total time=  10.9s
# [CV] END ..................................C=5, gamma=0.0009; total time=  11.3s
# [CV] END ..................................C=5, gamma=0.0009; total time=  11.4s
# [CV] END ..................................C=5, gamma=0.0009; total time=  11.3s
# [CV] END ..................................C=5, gamma=0.0009; total time=  11.7s
# [CV] END ..................................C=5, gamma=0.0009; total time=  11.7s
# [CV] END ...................................C=5, gamma=0.001; total time=  11.7s
# [CV] END ...................................C=5, gamma=0.001; total time=  11.4s
# [CV] END ...................................C=5, gamma=0.001; total time=  11.3s
# [CV] END ...................................C=5, gamma=0.001; total time=  11.7s
# [CV] END ..................................C=5, gamma=0.0011; total time=  11.6s
# [CV] END ...................................C=5, gamma=0.001; total time=  12.2s
# [CV] END ..................................C=5, gamma=0.0011; total time=  12.2s
# [CV] END ..................................C=5, gamma=0.0011; total time=  11.9s
# [CV] END ..................................C=5, gamma=0.0011; total time=  12.2s
# [CV] END ..................................C=5, gamma=0.0011; total time=  11.9s
# [CV] END ..................................C=5, gamma=0.0012; total time=  12.1s
# [CV] END ..................................C=5, gamma=0.0012; total time=  13.1s
# [CV] END ..................................C=5, gamma=0.0012; total time=  12.4s
# [CV] END ..................................C=5, gamma=0.0012; total time=  12.9s
# [CV] END ..................................C=5, gamma=0.0012; total time=  13.1s
# [CV] END ..................................C=5, gamma=0.0015; total time=  13.9s
# [CV] END ..................................C=5, gamma=0.0015; total time=  14.2s
# [CV] END ..................................C=8, gamma=0.0005; total time=  10.0s
# [CV] END ..................................C=8, gamma=0.0005; total time=  10.2s
# [CV] END ..................................C=5, gamma=0.0015; total time=  14.3s
# [CV] END ..................................C=8, gamma=0.0005; total time=   9.8s
# [CV] END ..................................C=5, gamma=0.0015; total time=  14.1s
# [CV] END ..................................C=8, gamma=0.0005; total time=   9.9s
# [CV] END ..................................C=8, gamma=0.0005; total time=   9.9s
# [CV] END ..................................C=5, gamma=0.0015; total time=  14.0s
# [CV] END ..................................C=8, gamma=0.0008; total time=  11.2s
# [CV] END ..................................C=8, gamma=0.0008; total time=  11.7s
# [CV] END ..................................C=8, gamma=0.0008; total time=  11.3s
# [CV] END ..................................C=8, gamma=0.0008; total time=  11.3s
# [CV] END ..................................C=8, gamma=0.0008; total time=  11.7s
# [CV] END ..................................C=8, gamma=0.0009; total time=  11.9s
# [CV] END ..................................C=8, gamma=0.0009; total time=  12.0s
# [CV] END ..................................C=8, gamma=0.0009; total time=  11.9s
# [CV] END ..................................C=8, gamma=0.0009; total time=  11.2s
# [CV] END ..................................C=8, gamma=0.0009; total time=  11.9s
# [CV] END ...................................C=8, gamma=0.001; total time=  12.2s
# [CV] END ...................................C=8, gamma=0.001; total time=  12.2s
# [CV] END ...................................C=8, gamma=0.001; total time=  12.4s
# [CV] END ...................................C=8, gamma=0.001; total time=  12.3s
# [CV] END ...................................C=8, gamma=0.001; total time=  12.3s
# [CV] END ..................................C=8, gamma=0.0011; total time=  12.6s
# [CV] END ..................................C=8, gamma=0.0011; total time=  12.1s
# [CV] END ..................................C=8, gamma=0.0011; total time=  12.6s
# [CV] END ..................................C=8, gamma=0.0011; total time=  12.8s
# [CV] END ..................................C=8, gamma=0.0011; total time=  13.0s
# [CV] END ..................................C=8, gamma=0.0012; total time=  13.1s
# [CV] END ..................................C=8, gamma=0.0012; total time=  13.5s
# [CV] END ..................................C=8, gamma=0.0012; total time=  13.1s
# [CV] END ..................................C=8, gamma=0.0012; total time=  12.9s
# [CV] END ..................................C=8, gamma=0.0012; total time=  12.7s
# [CV] END ..................................C=9, gamma=0.0005; total time=  10.2s
# [CV] END ..................................C=8, gamma=0.0015; total time=  14.6s
# [CV] END ..................................C=9, gamma=0.0005; total time=  10.5s
# [CV] END ..................................C=8, gamma=0.0015; total time=  14.6s
# [CV] END ..................................C=8, gamma=0.0015; total time=  15.1s
# [CV] END ..................................C=8, gamma=0.0015; total time=  14.3s
# [CV] END ..................................C=8, gamma=0.0015; total time=  14.8s
# [CV] END ..................................C=9, gamma=0.0005; total time=   9.5s
# [CV] END ..................................C=9, gamma=0.0005; total time=   9.8s
# [CV] END ..................................C=9, gamma=0.0005; total time=  10.4s
# [CV] END ..................................C=9, gamma=0.0008; total time=  11.7s
# [CV] END ..................................C=9, gamma=0.0008; total time=  11.8s
# [CV] END ..................................C=9, gamma=0.0008; total time=  11.9s
# [CV] END ..................................C=9, gamma=0.0008; total time=  11.5s
# [CV] END ..................................C=9, gamma=0.0008; total time=  11.8s
# [CV] END ..................................C=9, gamma=0.0009; total time=  11.5s
# [CV] END ..................................C=9, gamma=0.0009; total time=  11.9s
# [CV] END ..................................C=9, gamma=0.0009; total time=  12.0s
# [CV] END ..................................C=9, gamma=0.0009; total time=  11.7s
# [CV] END ..................................C=9, gamma=0.0009; total time=  12.1s
# [CV] END ...................................C=9, gamma=0.001; total time=  12.6s
# [CV] END ...................................C=9, gamma=0.001; total time=  12.7s
# [CV] END ...................................C=9, gamma=0.001; total time=  12.0s
# [CV] END ...................................C=9, gamma=0.001; total time=  12.2s
# [CV] END ...................................C=9, gamma=0.001; total time=  12.0s
# [CV] END ..................................C=9, gamma=0.0011; total time=  12.8s
# [CV] END ..................................C=9, gamma=0.0011; total time=  12.4s
# [CV] END ..................................C=9, gamma=0.0011; total time=  12.8s
# [CV] END ..................................C=9, gamma=0.0011; total time=  12.9s
# [CV] END ..................................C=9, gamma=0.0011; total time=  12.8s
# [CV] END ..................................C=9, gamma=0.0012; total time=  12.8s
# [CV] END ..................................C=9, gamma=0.0012; total time=  12.7s
# [CV] END ..................................C=9, gamma=0.0012; total time=  13.0s
# [CV] END ..................................C=9, gamma=0.0012; total time=  12.6s
# [CV] END ..................................C=9, gamma=0.0012; total time=  13.2s
# [CV] END ..................................C=9, gamma=0.0015; total time=  14.2s
# [CV] END ..................................C=9, gamma=0.0015; total time=  14.6s
# [CV] END ..................................C=9, gamma=0.0015; total time=  14.5s
# [CV] END ..................................C=9, gamma=0.0015; total time=  14.3s
# [CV] END .................................C=10, gamma=0.0005; total time=  10.0s
# [CV] END ..................................C=9, gamma=0.0015; total time=  15.0s
# [CV] END .................................C=10, gamma=0.0005; total time=   9.8s
# [CV] END .................................C=10, gamma=0.0005; total time=   9.6s
# [CV] END .................................C=10, gamma=0.0005; total time=  10.0s
# [CV] END .................................C=10, gamma=0.0005; total time=   9.9s
# [CV] END .................................C=10, gamma=0.0008; total time=  11.2s
# [CV] END .................................C=10, gamma=0.0008; total time=  11.3s
# [CV] END .................................C=10, gamma=0.0008; total time=  10.8s
# [CV] END .................................C=10, gamma=0.0008; total time=  11.5s
# [CV] END .................................C=10, gamma=0.0008; total time=  11.3s
# [CV] END .................................C=10, gamma=0.0009; total time=  11.4s
# [CV] END .................................C=10, gamma=0.0009; total time=  11.8s
# [CV] END .................................C=10, gamma=0.0009; total time=  11.9s
# [CV] END .................................C=10, gamma=0.0009; total time=  11.9s
# [CV] END .................................C=10, gamma=0.0009; total time=  12.1s
# [CV] END ..................................C=10, gamma=0.001; total time=  12.5s
# [CV] END ..................................C=10, gamma=0.001; total time=  13.1s
# [CV] END ..................................C=10, gamma=0.001; total time=  12.4s
# [CV] END ..................................C=10, gamma=0.001; total time=  11.8s
# [CV] END ..................................C=10, gamma=0.001; total time=  12.1s
# [CV] END .................................C=10, gamma=0.0011; total time=  12.9s
# [CV] END .................................C=10, gamma=0.0011; total time=  12.9s
# [CV] END .................................C=10, gamma=0.0011; total time=  12.7s
# [CV] END .................................C=10, gamma=0.0011; total time=  12.7s
# [CV] END .................................C=10, gamma=0.0011; total time=  13.3s
# [CV] END .................................C=10, gamma=0.0012; total time=  13.3s
# [CV] END .................................C=10, gamma=0.0012; total time=  13.0s
# [CV] END .................................C=10, gamma=0.0012; total time=  12.8s
# [CV] END .................................C=10, gamma=0.0012; total time=  12.9s
# [CV] END .................................C=10, gamma=0.0012; total time=  13.7s
# [CV] END .................................C=10, gamma=0.0015; total time=  14.4s
# [CV] END .................................C=10, gamma=0.0015; total time=  14.7s
# [CV] END .................................C=10, gamma=0.0015; total time=  14.8s
# [CV] END .................................C=11, gamma=0.0005; total time=  10.2s
# [CV] END .................................C=10, gamma=0.0015; total time=  14.6s
# [CV] END .................................C=10, gamma=0.0015; total time=  15.2s
# [CV] END .................................C=11, gamma=0.0005; total time=   9.8s
# [CV] END .................................C=11, gamma=0.0005; total time=   9.6s
# [CV] END .................................C=11, gamma=0.0005; total time=   9.6s
# [CV] END .................................C=11, gamma=0.0005; total time=   9.9s
# [CV] END .................................C=11, gamma=0.0008; total time=  11.9s
# [CV] END .................................C=11, gamma=0.0008; total time=  11.9s
# [CV] END .................................C=11, gamma=0.0008; total time=  12.1s
# [CV] END .................................C=11, gamma=0.0008; total time=  11.7s
# [CV] END .................................C=11, gamma=0.0008; total time=  11.9s
# [CV] END .................................C=11, gamma=0.0009; total time=  12.6s
# [CV] END .................................C=11, gamma=0.0009; total time=  12.8s
# [CV] END .................................C=11, gamma=0.0009; total time=  14.8s
# [CV] END .................................C=11, gamma=0.0009; total time=  15.1s
# [CV] END .................................C=11, gamma=0.0009; total time=  15.8s
# [CV] END ..................................C=11, gamma=0.001; total time=  16.4s
# [CV] END ..................................C=11, gamma=0.001; total time=  16.3s
# [CV] END ..................................C=11, gamma=0.001; total time=  16.2s
# [CV] END ..................................C=11, gamma=0.001; total time=  15.7s
# [CV] END ..................................C=11, gamma=0.001; total time=  15.5s
# [CV] END .................................C=11, gamma=0.0011; total time=  14.2s
# [CV] END .................................C=11, gamma=0.0011; total time=  14.9s
# [CV] END .................................C=11, gamma=0.0011; total time=  14.1s
# [CV] END .................................C=11, gamma=0.0011; total time=  13.9s
# [CV] END .................................C=11, gamma=0.0011; total time=  13.7s
# [CV] END .................................C=11, gamma=0.0012; total time=  14.1s
# [CV] END .................................C=11, gamma=0.0012; total time=  14.0s
# [CV] END .................................C=11, gamma=0.0012; total time=  14.4s
# [CV] END .................................C=11, gamma=0.0012; total time=  13.8s
# [CV] END .................................C=11, gamma=0.0012; total time=  14.7s
# [CV] END .................................C=11, gamma=0.0015; total time=  15.3s
# [CV] END .................................C=11, gamma=0.0015; total time=  15.8s
# [CV] END .................................C=12, gamma=0.0005; total time=  10.0s
# [CV] END .................................C=11, gamma=0.0015; total time=  15.5s
# [CV] END .................................C=11, gamma=0.0015; total time=  15.3s
# [CV] END .................................C=12, gamma=0.0005; total time=   9.9s
# [CV] END .................................C=11, gamma=0.0015; total time=  14.9s
# [CV] END .................................C=12, gamma=0.0005; total time=   9.7s
# [CV] END .................................C=12, gamma=0.0005; total time=   9.6s
# [CV] END .................................C=12, gamma=0.0005; total time=  10.3s
# [CV] END .................................C=12, gamma=0.0008; total time=  11.1s
# [CV] END .................................C=12, gamma=0.0008; total time=  11.4s
# [CV] END .................................C=12, gamma=0.0008; total time=  11.5s
# [CV] END .................................C=12, gamma=0.0008; total time=  10.7s
# [CV] END .................................C=12, gamma=0.0008; total time=  11.2s
# [CV] END .................................C=12, gamma=0.0009; total time=  12.1s
# [CV] END .................................C=12, gamma=0.0009; total time=  12.4s
# [CV] END .................................C=12, gamma=0.0009; total time=  11.5s
# [CV] END .................................C=12, gamma=0.0009; total time=  11.5s
# [CV] END .................................C=12, gamma=0.0009; total time=  12.3s
# [CV] END ..................................C=12, gamma=0.001; total time=  12.6s
# [CV] END ..................................C=12, gamma=0.001; total time=  12.3s
# [CV] END ..................................C=12, gamma=0.001; total time=  12.5s
# [CV] END ..................................C=12, gamma=0.001; total time=  12.0s
# [CV] END ..................................C=12, gamma=0.001; total time=  11.7s
# [CV] END .................................C=12, gamma=0.0011; total time=  13.0s
# [CV] END .................................C=12, gamma=0.0011; total time=  13.3s
# [CV] END .................................C=12, gamma=0.0011; total time=  13.2s
# [CV] END .................................C=12, gamma=0.0011; total time=  13.6s
# [CV] END .................................C=12, gamma=0.0011; total time=  13.6s
# [CV] END .................................C=12, gamma=0.0012; total time=  13.4s
# [CV] END .................................C=12, gamma=0.0012; total time=  13.5s
# [CV] END .................................C=12, gamma=0.0012; total time=  14.0s
# [CV] END .................................C=12, gamma=0.0012; total time=  13.7s
# [CV] END .................................C=12, gamma=0.0012; total time=  13.6s
# [CV] END .................................C=12, gamma=0.0015; total time=  15.4s
# [CV] END .................................C=12, gamma=0.0015; total time=  15.9s
# [CV] END .................................C=12, gamma=0.0015; total time=  15.2s
# [CV] END .................................C=12, gamma=0.0015; total time=  15.2s
# [CV] END .................................C=15, gamma=0.0005; total time=  10.4s
# [CV] END .................................C=15, gamma=0.0005; total time=   9.9s
# [CV] END .................................C=15, gamma=0.0005; total time=   9.5s
# [CV] END .................................C=12, gamma=0.0015; total time=  14.9s
# [CV] END .................................C=15, gamma=0.0005; total time=   9.5s
# [CV] END .................................C=15, gamma=0.0005; total time=   9.6s
# [CV] END .................................C=15, gamma=0.0008; total time=  11.4s
# [CV] END .................................C=15, gamma=0.0008; total time=  11.3s
# [CV] END .................................C=15, gamma=0.0008; total time=  11.0s
# [CV] END .................................C=15, gamma=0.0008; total time=  10.6s
# [CV] END .................................C=15, gamma=0.0008; total time=  11.1s
# [CV] END .................................C=15, gamma=0.0009; total time=  11.7s
# [CV] END .................................C=15, gamma=0.0009; total time=  11.7s
# [CV] END .................................C=15, gamma=0.0009; total time=  11.4s
# [CV] END .................................C=15, gamma=0.0009; total time=  11.2s
# [CV] END .................................C=15, gamma=0.0009; total time=  11.0s
# [CV] END ..................................C=15, gamma=0.001; total time=  11.8s
# [CV] END ..................................C=15, gamma=0.001; total time=  11.5s
# [CV] END ..................................C=15, gamma=0.001; total time=  11.9s
# [CV] END ..................................C=15, gamma=0.001; total time=  11.7s
# [CV] END ..................................C=15, gamma=0.001; total time=  12.3s
# [CV] END .................................C=15, gamma=0.0011; total time=  12.7s
# [CV] END .................................C=15, gamma=0.0011; total time=  12.6s
# [CV] END .................................C=15, gamma=0.0011; total time=  12.8s
# [CV] END .................................C=15, gamma=0.0011; total time=  12.5s
# [CV] END .................................C=15, gamma=0.0011; total time=  12.7s
# [CV] END .................................C=15, gamma=0.0012; total time=  12.8s
# [CV] END .................................C=15, gamma=0.0012; total time=  12.1s
# [CV] END .................................C=15, gamma=0.0012; total time=  12.0s
# [CV] END .................................C=15, gamma=0.0012; total time=  12.1s
# [CV] END .................................C=15, gamma=0.0012; total time=  11.8s
# [CV] END .................................C=15, gamma=0.0015; total time=  12.7s
# [CV] END .................................C=15, gamma=0.0015; total time=  12.0s
# [CV] END .................................C=15, gamma=0.0015; total time=  11.2s
# [CV] END .................................C=15, gamma=0.0015; total time=  10.0s
# [CV] END .................................C=15, gamma=0.0015; total time=   9.1s
# Best parameters found: {'C': 11, 'gamma': 0.0009}
# Best cross-validation accuracy: 93.43%

# %% [markdown]
# Best parameters found are C = 11 and gamma = 0.0009, yielding an accuracy of 93.43%
#
# ### Validation
#
# Now, let's validate this combination of hyperparameters on the test dataset

# %%
from sklearn.svm import SVC

svm_classifier = SVC(kernel='rbf', C=11, gamma=0.0009)
svm_classifier.fit(X_train_scaled, y_train)

test_accuracy = svm_classifier.score(X_test_scaled, y_test)
print(f"Test accuracy with C=11 and gamma=0.0009: {(test_accuracy * 100):.2f}%")
# Out:
# Test accuracy with C=11 and gamma=0.0009: 97.33%

# %% [markdown]
# # Part 2: One Versus All
# - Built-in binarization scheme used for SVC-class, namely one-vs-one and one-vs-all
# - Implement your own version of one-vs-all SVM and compare results against the built-in version
# - Keep the comparison simple by keeping the same hyperparameters you found in the first part
# - Which was the best classifier?
# - Stufy the confusion matrix and tell whether there was any apparent difference between the two methods in terms of missclassifications
#
# Train both OvA and OvO SVMs

# %%
from sklearn.base import BaseEstimator, ClassifierMixin
import numpy as np
from sklearn.metrics import confusion_matrix

class OneVsAllSVM(BaseEstimator, ClassifierMixin):
    def __init__(self, C=1.0, gamma='scale'):
        self.C = C
        self.gamma = gamma
        self.classifiers = []

    def fit(self, X, y):
        self.classes_ = np.unique(y)
        self.classifiers = []
        for cls in self.classes_:
            binary_y = np.where(y == cls, 1, 0)
            clf = SVC(kernel='rbf', C=self.C, gamma=self.gamma)
            clf.fit(X, binary_y)
            self.classifiers.append(clf)
        return self

    def predict(self, X):
        predictions = np.array([clf.decision_function(X) for clf in self.classifiers]).T
        return self.classes_[np.argmax(predictions, axis=1)]

ova_svm = OneVsAllSVM(C=11, gamma=0.0009)
ova_svm.fit(X_train_scaled, y_train)

ovo_svm = SVC(kernel='rbf', C=11, gamma=0.0009, decision_function_shape='ovo')
ovo_svm.fit(X_train_scaled, y_train)
# Out:
# SVC(C=11, decision_function_shape='ovo', gamma=0.0009)

# %%
from sklearn.metrics import confusion_matrix

ova_predictions = ova_svm.predict(X_test_scaled)
ova_test_accuracy = np.mean(ova_predictions == y_test) * 100
print(f"One-vs-All SVM Test accuracy: {ova_test_accuracy:.2f}%")
ova_conf_matrix = confusion_matrix(y_test, ova_predictions)
print("One-vs-All SVM Confusion Matrix:")
print(ova_conf_matrix)


ovo_predictions = ovo_svm.predict(X_test_scaled)
ovo_test_accuracy = np.mean(ovo_predictions == y_test) * 100
print(f"One-vs-One SVM Test accuracy: {ovo_test_accuracy:.2f}%")
ovo_conf_matrix = confusion_matrix(y_test, ovo_predictions)
print("One-vs-One SVM Confusion Matrix:")
print(ovo_conf_matrix)
# Out:
# One-vs-All SVM Test accuracy: 97.66%
# One-vs-All SVM Confusion Matrix:
# [[ 970    0    1    0    1    1    3    2    2    0]
#  [   0 1126    3    0    0    1    3    1    1    0]
#  [   3    1  999    3    2    0    2   13    8    1]
#  [   1    0    1  991    0    5    0    4    4    4]
#  [   1    0    4    1  954    1    4    5    3    9]
#  [   2    0    0    6    0  872    2    4    5    1]
#  [   2    2    1    1    3    5  941    2    1    0]
#  [   0    4    9    1    2    1    0  993    4   14]
#  [   1    0    2    4    3    5    1    7  949    2]
#  [   3    3    3    5    8    2    0   10    4  971]]
# One-vs-One SVM Test accuracy: 97.33%
# One-vs-One SVM Confusion Matrix:
# [[ 968    0    3    2    1    2    1    1    2    0]
#  [   0 1128    3    0    0    1    2    1    0    0]
#  [   6    2 1001    0    2    0    1   12    7    1]
#  [   0    0    3  987    1    6    0    5    7    1]
#  [   0    0    5    0  956    1    3    6    2    9]
#  [   3    0    0    9    2  864    3    5    5    1]
#  [   4    2    1    0    3    9  934    2    3    0]
#  [   0    4   10    2    3    0    0  997    1   11]
#  [   3    2    3    5    4    8    2    9  932    6]
#  [   2    4    2    8   10    3    0   11    3  966]]

# %% [markdown]
# ### Discussion
# In conclusion, the comparison between the One-vs-All (OvA) and One-vs-One (OvO) SVM approaches on the MNIST dataset reveals that both methods are highly effective, achieving test accuracies of 97.66% and 97.33%, respectively. The slight edge in accuracy for the OvA approach suggests it may handle certain class distinctions better, though both models exhibit similar patterns of misclassification, particularly among visually similar digits. Generally, the choice between OvA and OvO depends on computational resources, as OvA tends to be more resource-efficient due to its simpler model structure. In this case, OvA is preferred due to both lower resource demand and higher accuracy.
